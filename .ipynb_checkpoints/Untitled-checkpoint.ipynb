# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Random Forest Classifiers
#
# #### Vervolg op workshop Random Forest Classifiers

# %%
heart_df = pd.read_csv('heart.csv')
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_9c884d34_8de7_11ea_a31d_ecb1d7c13ac2row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9c884d34_8de7_11ea_a31d_ecb1d7c13ac2row0_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_9c884d34_8de7_11ea_a31d_ecb1d7c13ac2row0_col2 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_9c884d34_8de7_11ea_a31d_ecb1d7c13ac2row0_col3 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_9c884d34_8de7_11ea_a31d_ecb1d7c13ac2row0_col4 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_9c884d34_8de7_11ea_a31d_ecb1d7c13ac2row0_col5 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_9c884d34_8de7_11ea_a31d_ecb1d7c13ac2row0_col6 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
# ...

# %%
def create_rfc(num_trees, max_features=None, max_depth=None, random_state=0):
    
    for t in num_trees:
        
        dtc = DecisionTreeClassifier(random_state=random_state, max_features=max_features, max_depth=max_depth)
